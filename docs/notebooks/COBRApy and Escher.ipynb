# %%
import escher
import escher.urls
import cobra
import cobra.test
import json
import os
from IPython.display import HTML

# %%
d = escher.urls.root_directory
print 'Escher directory: %s' % d
# Out:
# Escher directory: /Users/zaking/repos/escher

# %% [markdown]
# ### Embed an Escher map in an IPython notebook

# %%
escher.list_available_maps()
# Out:
# [{u'map_name': u'E coli core.Core metabolism',
#   u'organism': u'Escherichia coli'},
#  {u'map_name': u'iJO1366.Central metabolism',
#   u'organism': u'Escherichia coli'},
#  {u'map_name': u'iJO1366.Fatty acid metabolism',
#   u'organism': u'Escherichia coli'}]

# %%
b = escher.Builder(map_name='iJO1366.Central metabolism')
b.display_in_notebook()
# Out:
#   <!-- These are not generally used within the notebook. -->
#   <script src=""></script>
#   <script src=""></script>
#
#   <link rel="stylesheet" href=""/>
#   <link rel="stylesheet" href="//escher.github.io/builder-1.0.0.css"/>
#
#
#
#   <div style="height: 500px; width: 100%;" id="lggnllhgqt"></div>
#
#   <script>
#    var map_data_lggnllhgqt = [{"map_name": "", "map_id": "", "map_description": "", "homepage": "https://zakandrewking.github.io/escher", "schema": "https://zakandrewking.github.io/escher/escher/jsonschema/1-0-0#"}, {"reactions": {"2075993": {"name": "transketolase", "label_x": 2746.858, "segments": {"392": {"to_node_id": "2075696", "b1": {"y": 2187.0637816618037, "x": 2729.6511095298383}, "b2": {"y": 2249.701676633095, "x": 2727.993234891127}, "from_node_id": "2076427"}, "391": {"to_node_id": "2075576", "b1": {"y": 2930.3798701240066, "x": 2873.4532466011083}, "b2": {"y": 2685.346287913356, "x": 3229.0630212224432}, "from_node_id": "2076427"}, "390": {"to_node_id": "2076428", "b1": {"y": 1986.0539705934898, "x": 2722.3384189548324}, "b2": {"y": 2052.3273311780467, "x": 2729.70212568645}, "from_node_id": "2075464"}, "387": {"to_node_id": "2076429", "b1": null, "b2": null, "from_node_id": "2076428"}, "388": {"to_node_id": "2076427", "b1": null, "b2": null, "from_node_id": "2076429"}, "389": {"to_node_id": "2076428", "b1": {"y": 1984.7187677538805, "x": 2722.1900630837645}, "b2": {"y": 2051.926770326164, "x": 2729.6576189251296}, "from_node_id": "2075603"}}, "genes": [{"bigg_id": "b2935", "name": "b2935"}, {"bigg_id": "b2465", "name": "b2465"}], "reversibility": true, "metabolites": [{"coefficient": 1.0, "bigg_id": "s7p_c"}, {"coefficient": -1.0, "bigg_id": "xu5p__D_c"}, {"coefficient": 1.0, "bigg_id": "g3p_c"}, {"coefficient": -1.0, "bigg_id": "r5p_c"}], "bigg_id": "TKT1", "label_y": 2106.7302, "gene_reaction_rule": "(b2935 or b2465)"}, "2075992": {"name": "Glycolate oxidase", "label_x": 7266.858, "segments": {"381": {"to_node_id": "2076425", "b1": null, "b2": null, "from_node_id": "2076424"}, "382": {"to_node_id": "2076426", "b1": null, "b2": null, "from_node_id": "2076425"}, "383": {"to_node_id": "2076424", "b1": {"y": 1846.1468151627328, "x": 7256.858}, "b2": {"y": 1798.9551845488197, "x": 7256.858}, "from_node_id": "2075724"}, "384": {"to_node_id": "2076424", "b1": {"y": 2034.779023469275, "x": 7256.858}, "b2": {"y": 1855.5448470407825, "x": 7256.858}, "from_node_id": "2075300"}, "385": {"to_node_id": "2075296", "b1": {"y": 1594.9049935861033, "x": 7256.858}, "b2": {"y": 1259.312845287011, "x": 7256.858}, "from_node_id": "2076426"}, "386": {"to_node_id": "2075725", "b1": {"y": 1714.046197083131, "x": 7256.858}, "b2": {"y": 1656.450190277103, "x": 7256.858}, "from_node_id": "2076426"}}, "genes": [{"bigg_id": "b2979", "name": "b2979"}, {"bigg_id": "b4467", "name": "b4467"}, {"bigg_id": "b4468", "name": "b4468"}], "reversibility": false, "metabolites": [{"coefficient": -1.0, "bigg_id": "glyclt_c"}, {"coefficient": 1.0, "bigg_id": "q8h2_c"}, {"coefficient": -1.0, "bigg_id": "q8_c"}, {"coefficient": 1.0, "bigg_id": "glx_c"}], "bigg_id": "GLYCTO2", "label_y": 1748.7302, "gene_reaction_rule": "(b2979 and b4467 and b4468)"}, "2075991": {"name": "pyruvate reversible transport via proton symport (periplasm)", "label_x": 1256.8579, "segments": {"379": {"to_node_id": "2075723", "b1": {"y": 5326.050855384039, "x": 1248.09399862492}, "b2": {"y": 5263.799517946799, "x": 1248.6448954164}, "from_node_id": "2076421"}, "380": {"to_node_id": "2075490", "b1": {"y": 5138.149918948313, "x": 1260.0619367723048}, "b2": {"y": 4646.9152115985435, "x": 1682.966977652474}, "from_node_id": "2076421"}, "378": {"to_node_id": "2076423", "b1": {"y": 5647.723725023937, "x": 1248.9497818968268}, "b2": {"y": 5581.22811750718, "x": 1248.185464569048}, "from_node_id": "2075722"}, "375": {"to_node_id": "2076422", "b1": null, "b2": null, "from_node_id": "2076423"}, "377": {"to_node_id": "2076423", "b1": {"y": 5626.054891156714, "x": 1248.7007148408818}, "b2": {"y": 5574.727467347014, "x": 1248.1107444522645}, "from_node_id": "2075721"}, "376": {"to_node_id": "2076421", "b1": null, "b2": null, "from_node_id": "2076422"}}, "genes": [], "reversibility": true, "metabolites": [{"coefficient": -1.0, "bigg_id": "h_p"}, {"coefficient": -1.0, "bigg_id": "pyr_p"}, {"coeffic ...

# %% [markdown]
# ### Plot FBA solutions in Escher

# %%
model = cobra.io.load_json_model(cobra.test.ecoli_json)
solution = model.optimize()
print 'Growth rate: %.2f' % solution.f
# Out:
# Growth rate: 0.98

# %%
b = escher.Builder(map_name='iJO1366.Central metabolism',
                   reaction_data=solution.x_dict,
                   # color and size according to the absolute value
                   reaction_styles=['color', 'size', 'abs', 'text'],
                   # change the default colors
                   reaction_scale=[{'type': 'min', 'color': '#cccccc', 'size': 4},
                                   {'type': 'mean', 'color': '#0000dd', 'size': 20},
                                   {'type': 'max', 'color': '#ff0000', 'size': 40}],
                   # only show the primary metabolites
                   hide_secondary_metabolites=True)
b.display_in_notebook()
# Out:
#   <!-- These are not generally used within the notebook. -->
#   <script src=""></script>
#   <script src=""></script>
#
#   <link rel="stylesheet" href=""/>
#   <link rel="stylesheet" href="//escher.github.io/builder-1.0.0.css"/>
#
#
#
#   <div style="height: 500px; width: 100%;" id="amgsmsmcpx"></div>
#
#   <script>
#    var map_data_amgsmsmcpx = [{"map_name": "", "map_id": "", "map_description": "", "homepage": "https://zakandrewking.github.io/escher", "schema": "https://zakandrewking.github.io/escher/escher/jsonschema/1-0-0#"}, {"reactions": {"2075993": {"name": "transketolase", "label_x": 2746.858, "segments": {"392": {"to_node_id": "2075696", "b1": {"y": 2187.0637816618037, "x": 2729.6511095298383}, "b2": {"y": 2249.701676633095, "x": 2727.993234891127}, "from_node_id": "2076427"}, "391": {"to_node_id": "2075576", "b1": {"y": 2930.3798701240066, "x": 2873.4532466011083}, "b2": {"y": 2685.346287913356, "x": 3229.0630212224432}, "from_node_id": "2076427"}, "390": {"to_node_id": "2076428", "b1": {"y": 1986.0539705934898, "x": 2722.3384189548324}, "b2": {"y": 2052.3273311780467, "x": 2729.70212568645}, "from_node_id": "2075464"}, "387": {"to_node_id": "2076429", "b1": null, "b2": null, "from_node_id": "2076428"}, "388": {"to_node_id": "2076427", "b1": null, "b2": null, "from_node_id": "2076429"}, "389": {"to_node_id": "2076428", "b1": {"y": 1984.7187677538805, "x": 2722.1900630837645}, "b2": {"y": 2051.926770326164, "x": 2729.6576189251296}, "from_node_id": "2075603"}}, "genes": [{"bigg_id": "b2935", "name": "b2935"}, {"bigg_id": "b2465", "name": "b2465"}], "reversibility": true, "metabolites": [{"coefficient": 1.0, "bigg_id": "s7p_c"}, {"coefficient": -1.0, "bigg_id": "xu5p__D_c"}, {"coefficient": 1.0, "bigg_id": "g3p_c"}, {"coefficient": -1.0, "bigg_id": "r5p_c"}], "bigg_id": "TKT1", "label_y": 2106.7302, "gene_reaction_rule": "(b2935 or b2465)"}, "2075992": {"name": "Glycolate oxidase", "label_x": 7266.858, "segments": {"381": {"to_node_id": "2076425", "b1": null, "b2": null, "from_node_id": "2076424"}, "382": {"to_node_id": "2076426", "b1": null, "b2": null, "from_node_id": "2076425"}, "383": {"to_node_id": "2076424", "b1": {"y": 1846.1468151627328, "x": 7256.858}, "b2": {"y": 1798.9551845488197, "x": 7256.858}, "from_node_id": "2075724"}, "384": {"to_node_id": "2076424", "b1": {"y": 2034.779023469275, "x": 7256.858}, "b2": {"y": 1855.5448470407825, "x": 7256.858}, "from_node_id": "2075300"}, "385": {"to_node_id": "2075296", "b1": {"y": 1594.9049935861033, "x": 7256.858}, "b2": {"y": 1259.312845287011, "x": 7256.858}, "from_node_id": "2076426"}, "386": {"to_node_id": "2075725", "b1": {"y": 1714.046197083131, "x": 7256.858}, "b2": {"y": 1656.450190277103, "x": 7256.858}, "from_node_id": "2076426"}}, "genes": [{"bigg_id": "b2979", "name": "b2979"}, {"bigg_id": "b4467", "name": "b4467"}, {"bigg_id": "b4468", "name": "b4468"}], "reversibility": false, "metabolites": [{"coefficient": -1.0, "bigg_id": "glyclt_c"}, {"coefficient": 1.0, "bigg_id": "q8h2_c"}, {"coefficient": -1.0, "bigg_id": "q8_c"}, {"coefficient": 1.0, "bigg_id": "glx_c"}], "bigg_id": "GLYCTO2", "label_y": 1748.7302, "gene_reaction_rule": "(b2979 and b4467 and b4468)"}, "2075991": {"name": "pyruvate reversible transport via proton symport (periplasm)", "label_x": 1256.8579, "segments": {"379": {"to_node_id": "2075723", "b1": {"y": 5326.050855384039, "x": 1248.09399862492}, "b2": {"y": 5263.799517946799, "x": 1248.6448954164}, "from_node_id": "2076421"}, "380": {"to_node_id": "2075490", "b1": {"y": 5138.149918948313, "x": 1260.0619367723048}, "b2": {"y": 4646.9152115985435, "x": 1682.966977652474}, "from_node_id": "2076421"}, "378": {"to_node_id": "2076423", "b1": {"y": 5647.723725023937, "x": 1248.9497818968268}, "b2": {"y": 5581.22811750718, "x": 1248.185464569048}, "from_node_id": "2075722"}, "375": {"to_node_id": "2076422", "b1": null, "b2": null, "from_node_id": "2076423"}, "377": {"to_node_id": "2076423", "b1": {"y": 5626.054891156714, "x": 1248.7007148408818}, "b2": {"y": 5574.727467347014, "x": 1248.1107444522645}, "from_node_id": "2075721"}, "376": {"to_node_id": "2076421", "b1": null, "b2": null, "from_node_id": "2076422"}}, "genes": [], "reversibility": true, "metabolites": [{"coefficient": -1.0, "bigg_id": "h_p"}, {"coefficient": -1.0, "bigg_id": "pyr_p"}, {"coeffic ...

# %% [markdown]
# ### Use a COBRA model from the IPython Notebook to edit maps

# %%
model_modified = model.copy()
# for example, delete a reaction
model_modified.reactions.GAPD.delete()

# %%
# pass the model to a new builder
b = escher.Builder(map_name='iJO1366.Central metabolism',
                   model=model_modified,
                   # in the map, highlight all reactions that are missing from the model
                   highlight_missing=True)
b.display_in_notebook()
# Out:
#   <!-- These are not generally used within the notebook. -->
#   <script src=""></script>
#   <script src=""></script>
#
#   <link rel="stylesheet" href=""/>
#   <link rel="stylesheet" href="//escher.github.io/builder-1.0.0.css"/>
#
#
#
#   <div style="height: 500px; width: 100%;" id="punrgefypl"></div>
#
#   <script>
#    var map_data_punrgefypl = [{"map_name": "", "map_id": "", "map_description": "", "homepage": "https://zakandrewking.github.io/escher", "schema": "https://zakandrewking.github.io/escher/escher/jsonschema/1-0-0#"}, {"reactions": {"2075993": {"name": "transketolase", "label_x": 2746.858, "segments": {"392": {"to_node_id": "2075696", "b1": {"y": 2187.0637816618037, "x": 2729.6511095298383}, "b2": {"y": 2249.701676633095, "x": 2727.993234891127}, "from_node_id": "2076427"}, "391": {"to_node_id": "2075576", "b1": {"y": 2930.3798701240066, "x": 2873.4532466011083}, "b2": {"y": 2685.346287913356, "x": 3229.0630212224432}, "from_node_id": "2076427"}, "390": {"to_node_id": "2076428", "b1": {"y": 1986.0539705934898, "x": 2722.3384189548324}, "b2": {"y": 2052.3273311780467, "x": 2729.70212568645}, "from_node_id": "2075464"}, "387": {"to_node_id": "2076429", "b1": null, "b2": null, "from_node_id": "2076428"}, "388": {"to_node_id": "2076427", "b1": null, "b2": null, "from_node_id": "2076429"}, "389": {"to_node_id": "2076428", "b1": {"y": 1984.7187677538805, "x": 2722.1900630837645}, "b2": {"y": 2051.926770326164, "x": 2729.6576189251296}, "from_node_id": "2075603"}}, "genes": [{"bigg_id": "b2935", "name": "b2935"}, {"bigg_id": "b2465", "name": "b2465"}], "reversibility": true, "metabolites": [{"coefficient": 1.0, "bigg_id": "s7p_c"}, {"coefficient": -1.0, "bigg_id": "xu5p__D_c"}, {"coefficient": 1.0, "bigg_id": "g3p_c"}, {"coefficient": -1.0, "bigg_id": "r5p_c"}], "bigg_id": "TKT1", "label_y": 2106.7302, "gene_reaction_rule": "(b2935 or b2465)"}, "2075992": {"name": "Glycolate oxidase", "label_x": 7266.858, "segments": {"381": {"to_node_id": "2076425", "b1": null, "b2": null, "from_node_id": "2076424"}, "382": {"to_node_id": "2076426", "b1": null, "b2": null, "from_node_id": "2076425"}, "383": {"to_node_id": "2076424", "b1": {"y": 1846.1468151627328, "x": 7256.858}, "b2": {"y": 1798.9551845488197, "x": 7256.858}, "from_node_id": "2075724"}, "384": {"to_node_id": "2076424", "b1": {"y": 2034.779023469275, "x": 7256.858}, "b2": {"y": 1855.5448470407825, "x": 7256.858}, "from_node_id": "2075300"}, "385": {"to_node_id": "2075296", "b1": {"y": 1594.9049935861033, "x": 7256.858}, "b2": {"y": 1259.312845287011, "x": 7256.858}, "from_node_id": "2076426"}, "386": {"to_node_id": "2075725", "b1": {"y": 1714.046197083131, "x": 7256.858}, "b2": {"y": 1656.450190277103, "x": 7256.858}, "from_node_id": "2076426"}}, "genes": [{"bigg_id": "b2979", "name": "b2979"}, {"bigg_id": "b4467", "name": "b4467"}, {"bigg_id": "b4468", "name": "b4468"}], "reversibility": false, "metabolites": [{"coefficient": -1.0, "bigg_id": "glyclt_c"}, {"coefficient": 1.0, "bigg_id": "q8h2_c"}, {"coefficient": -1.0, "bigg_id": "q8_c"}, {"coefficient": 1.0, "bigg_id": "glx_c"}], "bigg_id": "GLYCTO2", "label_y": 1748.7302, "gene_reaction_rule": "(b2979 and b4467 and b4468)"}, "2075991": {"name": "pyruvate reversible transport via proton symport (periplasm)", "label_x": 1256.8579, "segments": {"379": {"to_node_id": "2075723", "b1": {"y": 5326.050855384039, "x": 1248.09399862492}, "b2": {"y": 5263.799517946799, "x": 1248.6448954164}, "from_node_id": "2076421"}, "380": {"to_node_id": "2075490", "b1": {"y": 5138.149918948313, "x": 1260.0619367723048}, "b2": {"y": 4646.9152115985435, "x": 1682.966977652474}, "from_node_id": "2076421"}, "378": {"to_node_id": "2076423", "b1": {"y": 5647.723725023937, "x": 1248.9497818968268}, "b2": {"y": 5581.22811750718, "x": 1248.185464569048}, "from_node_id": "2075722"}, "375": {"to_node_id": "2076422", "b1": null, "b2": null, "from_node_id": "2076423"}, "377": {"to_node_id": "2076423", "b1": {"y": 5626.054891156714, "x": 1248.7007148408818}, "b2": {"y": 5574.727467347014, "x": 1248.1107444522645}, "from_node_id": "2075721"}, "376": {"to_node_id": "2076421", "b1": null, "b2": null, "from_node_id": "2076422"}}, "genes": [], "reversibility": true, "metabolites": [{"coefficient": -1.0, "bigg_id": "h_p"}, {"coefficient": -1.0, "bigg_id": "pyr_p"}, {"coeffic ...

# %%
# open the Builder in a new tab to edit this map with your modified model
b.display_in_browser()
